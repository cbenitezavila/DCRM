# %% [markdown]
# # Import

# %%
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt

import networkx as nx
import numpy as np

import copy

from shapely.geometry import Polygon

# %% [markdown]
# # Data exploration of the conflict data
#
# * Goal is to do some graphs to elaborate on the cooccurance of mines and conflicts

# %% [markdown]
# ## Transformations

# %%
cf = pd.read_excel('data\EJAtlas_dataset_V1_2024-01.xlsx', sheet_name='EJAtlas Data', skiprows=[0])

# %%
cf.head()
# Out:
#    Conflict Id         Country  \
# 0            3         Germany
# 1            4  United Kingdom
# 2            5          France
# 3            6         Germany
# 4            7           Spain
#
#                                               Case                  Site  \
# 0                    Stuttgart 21 Project, Germany             Stuttgart
# 1           High Speed Two railway, United Kingdom     Several (Railway)
# 2                 Nice - OIN plaine du Var, France                  Nice
# 3       Fehmarn Belt Fixed Link, Germany - Denmark  Ostholstein/ Lolland
# 4  Trans-Pyrenean Central Corridor, Spain - France                   NaN
#
#                                   Province               Lon  \
# 0                        Baden-Württemberg  9.19735908508301
# 1     London, East Midlands, West Midlands    -0.10986328125
# 2                Provence-Alpes Cote dAzur  7.24239349365234
# 3       Schleswig-Holstein/ Region Zealand  11.2898254394531
# 4  Aragon (Spain), Midi-Pyrénées (France )  -0.2032470703125
#
#                 Lat     Accuracy of location  \
# 0  48.7964046844567         HIGH local level
# 1  51.4882243263235  LOW country/state level
# 2  43.7108197524576    MEDIUM regional level
# 3  54.5771678087124    MEDIUM regional level
# 4  42.7991771735111    MEDIUM regional level
#
#                                          Description  \
# 0  <p>Stuttgart 21 is a railway and urban develop...
# 1  <p>High Speed 2 (HS2) is a planned high-speed ...
# 2  <p>The OIN (Operation d Intérêt National) Eco-...
# 3  <p>The Fehmarn Belt Fixed Link is an immersed ...
# 4  <p>The Trans-Pyrenean Central Corridor (TCP in...
#
#                                      Project Details  ...  \
# 0  33 kilometers of additional tunnels.\n25 kilom...  ...
# 1                         Width: 72 m Speed: 400 kph  ...
# 2  Construction of Olympic Nice Stadium.\nIkea st...  ...
# 3  17.6 km of immersed tunnel: 40 m wide, almost ...  ...
# 4  Several tunnels. The longest could be of about...  ...
#
#   SecImpact: Land dispossession SecImpact: Loss of landscape/sense of place  \
# 0                             0                                           P
# 1                             P                                           P
# 2                             P                                           P
# 3                             0                                           0
# 4                             0                                           P
#
#   SecImpact: Other socio-economic impacts Other Sec Impacts  \
# 0                                       0               NaN
# 1                                       0               NaN
# 2                                       0               NaN
# 3                                       0               NaN
# 4                                       0               NaN
#
#                                           References  \
# 0                                                NaN
# 1  Department for Transport (2013). High Speed 2:...
# 2  An article with a positive view of the project...
# 3  Fixed Link (2009). Fehmarn Belt. Review of a f...
# 4  Article supporting the project:\n\n\nVal, S. a...
#
#                                         Legislations  \
# 0                                                NaN
# 1                              EU Directive 96/48/EC
# 2  Décret n° 2008-773 du 30 juillet 2008 portant ...
# 3                                                NaN
# 4  Proposal for a REGULATION OF THE EUROPEAN PARL...
#
#                                             Weblinks  \
# 0  http://goo.gl/OXBCu4\n\nArticles in the Englis...
# 1  HS2 Project web page:\nhttp://www.hs2.org.uk/\...
# 2  Another website promoting the project:\nhttp:/...
# 3  NABU analysis of economic concerns and environ...
# 4  French association defending the project (in F...
#
#                                           Medialinks               Created At  \
# 0  Euronews europeans: Stuttgart 21: dividing a c...  2014-03-11 19:18:02 UTC
# 1  BBC Countryfile report on HS2 threat to Chilte...  2014-03-11 19:18:03 UTC
# 2  Videos of the actions carried out by the oppos...  2014-03-11 19:18:03 UTC
# 3  Fehmarn Belt Fixed Link - bridge between Denma...  2014-03-11 19:18:04 UTC
# 4  Actival association website (in French)\nhttp:...  2014-03-11 19:18:04 UTC
#
#                Modified At
# 0  2015-01-26 09:05:48 UTC
# 1  2014-04-08 15:06:33 UTC
# 2  2014-04-08 15:04:04 UTC
# 3  2014-06-24 07:42:52 UTC
# 4  2015-01-26 09:04:15 UTC
#
# [5 rows x 263 columns]

# %% [markdown]
# filter for all cases that contain the words mining.
#
# Therefore i query for
#
# col_int = ['Type: Uranium extraction',
#            'Type: Mineral ore exploration',
#            'Type: Mineral processing',
#            'Type: Tailings from mines',
#            'Type: Landfills, toxic waste treatment, uncontrolled dump sites'
# ]
#
#
# i leaf the Metal refinieries out as the scope of teh work is extraction

# %%
cf.columns
# Out:
# Index(['Conflict Id', 'Country', 'Case', 'Site', 'Province', 'Lon', 'Lat',
#        'Accuracy of location', 'Description', 'Project Details',
#        ...
#        'SecImpact: Land dispossession',
#        'SecImpact: Loss of landscape/sense of place',
#        'SecImpact: Other socio-economic impacts', 'Other Sec Impacts',
#        'References', 'Legislations', 'Weblinks', 'Medialinks', 'Created At',
#        'Modified At'],
#       dtype='object', length=263)

# %%
col_int = ['Type: Uranium extraction', 
           'Type: Mineral ore exploration',
           'Type: Mineral processing',
           'Type: Tailings from mines',
           'Type: Landfills, toxic waste treatment, uncontrolled dump sites'    
           ]

mask = cf[col_int].eq(1).any(axis=1)

# %%
cfm = cf[mask]

# %%
cfm.shape[0] /cf.shape[0]
# Out:
# 0.2851592851592852

# %% [markdown]
# In the Subset we have 1101 mining related conflicts. this are approx 30\% of all conflicts. Roughly the amount mentioned in the paper Lets fix the long lat of the subset
#
# Transformation: The rstrip() method removes any trailing characters (characters at the end a string), space is the default trailing character to remove.
#
# Striped the . at the end.

# %%
cfm['Lon'] = cfm['Lon'].astype(str).str.rstrip('.')
cfm['Lat'] = cfm['Lat'].astype(str).str.rstrip('.')
cfm[['Lon', 'Lat']] = cfm[['Lon', 'Lat']].astype(float)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_11232\501545020.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cfm['Lon'] = cfm['Lon'].astype(str).str.rstrip('.')
# C:\Users\admin\AppData\Local\Temp\ipykernel_11232\501545020.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cfm['Lat'] = cfm['Lat'].astype(str).str.rstrip('.')
# C:\Users\admin\AppData\Local\Temp\ipykernel_11232\501545020.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cfm[['Lon', 'Lat']] = cfm[['Lon', 'Lat']].astype(float)

# %%
cfm.plot.scatter(x='Lon', y='Lat')
# Out:
# <Axes: xlabel='Lon', ylabel='Lat'>

# %%
cg = gpd.GeoDataFrame(cfm, geometry=gpd.points_from_xy(cfm.Lon, cfm.Lat))

# %% [markdown]
# ## Analysis of spatial density of conflicts

# %%
cg.plot(markersize=5)
# Out:
# <Axes: >

# %%
sns.kdeplot(x=cg['Lon'], y=cg['Lat'], cmap='viridis', fill=True, bw_adjust=.1)
# Out:
# <Axes: xlabel='Lon', ylabel='Lat'>

# %% [markdown]
# ## Discussion map building
#
# * mining polygons
# * conflict
# * mine centroids + buffer
#
# do two bounding boxes around focus areas

# %%
poly = gpd.read_file('data\mine-comm\global_mining_land_use_comm.gpkg')

# %%
poly_m = poly.to_crs('EPSG:3857')

# %%
poly_m['buf_50km'] = poly_m.centroid.buffer(5*10**4)

# %%
poly_m.buf_50km.plot()
# Out:
# <Axes: >

# %%
poly_trans = poly_m.to_crs('EPSG:4326')

# %%
poly_trans['buf_50km'].plot()
# Out:
# <Axes: >

# %%
cg.set_crs('EPSG:4326', inplace=True)
# Out:
#       Conflict Id                   Country  \
# 14             19  United States of America
# 15             20  United States of America
# 18             23  United States of America
# 19             24  United States of America
# 23             28                  Tanzania
# ...           ...                       ...
# 3847         6371                 Greenland
# 3850         6376                     Chile
# 3853         6385                Madagascar
# 3855         6387                     Italy
# 3860         6393                    Mexico
#
#                                                    Case  \
# 14    Emelle nation's largest hazardous waste landfi...
# 15              PCB Contamination in Warren County, USA
# 18    Toxic Waste Landfill in Kettleman City, Calif....
# 19       Clustering of Waste Facilities in Chester, USA
# 23             Soda ash mining in Lake Natron, Tanzania
# ...                                                 ...
# 3847   Black Angel zinc-lead mine since 1972. Greenland
# 3850  Minería de Tierras Raras en Penco, Región del ...
# 3853  Maniry graphite project in Ambohitsy Haut, Mad...
# 3855  Estrazione di idrocarburi Total | Tempa Rossa,...
# 3860  Guadalcazar, hazardous waste dumping by USA fi...
#
#                                                    Site  \
# 14                               Emelle (Sumter County)
# 15                                        Warren County
# 18                                       Kettleman City
# 19                                              Chester
# 23                                      Arusha District
# ...                                                 ...
# 3847                                         Maamorilik
# 3850                                              Penco
# 3853                                     Ambohitsy Haut
# 3855  Alta Valle del Sauro e Val Camastra, Comuni di...
# 3860                                        Guadalcazar
#
#                                                Province         Lon  \
# 14                                              Alabama  -88.308805
# 15                                       North Carolina  -78.173911
# 18                                           California -119.963690
# 19                                         Pennsylvania  -75.405589
# 23                                    Northern Tanzania   36.135653
# ...                                                 ...         ...
# 3847                                          Avannaata  -51.273300
# 3850            Provincia de Concepción, Región Bio-Bío  -72.962500
# 3853                                            Toliara   44.816677
# 3855  Provincia di Potenza, Provincia di Matera, Bas...   16.041540
# 3860                                    San Luis Potosi -100.397800
#
#             Lat   Accuracy of location  \
# 14    32.796690       HIGH local level
# 15    36.336907  MEDIUM regional level
# 18    35.998650       HIGH local level
# 19    39.825152  MEDIUM regional level
# 23    -2.283979  MEDIUM regional level
# ...         ...                    ...
# 3847  71.122400       HIGH local level
# 3850 -36.735000  MEDIUM regional level
# 3853 -24.499940  MEDIUM regional level
# 3855  40.380440  MEDIUM regional level
# 3860  22.623830       HIGH local level
#
#                                             Description  \
# 14    <p>In 1978, Chemical Waste Management, a subsi...
# 15    <p>Warren County was one of the first cases of...
# 18    <p>Kings County is a county in California’s Sa...
# 19    <p>Chester, a city located within Delaware Cou...
# 23    <p>Lake Natron Resources Limited, a company jo...
# ...                                                 ...
# 3847  <p>Danish geologists started to explore The Bl...
# 3850  <p>Desde 2015, en los cerros de la ciudad de P...
# 3853  <p>Australian mining company Evion, formerly k...
# 3855  <p>Tempa Rossa è un giacimento petrolifero si...
# 3860  <p>&nbsp;El CIADI protege a las industrias con...
#
#                                         Project Details  ...  \
# 14    At its peak, the company received almost 800,0...  ...
# 15          40,000 cubic yards of PCB contaminated soil  ...
# 18    Chemical waste disposal and treatment site wit...  ...
# 19    Westinghouse Resource Recovery Facility burns ...  ...
# 23    The company plans to produce 0.5 million tonne...  ...
# ...                                                 ...  ...
# 3847  Size of he mine: 5 sq km (500 hectares). The P...  ...
# 3850  Inicialmente, el proyecto de la empresa chilen...  ...
# 3853  - The mine's projected lifespan is 21 years [9...  ...
# 3855  Lo sviluppo del progetto prevede la costruzion...  ...
# 3860  Metalclad Corporation c. los Estados Unidos Me...  ...
#
#      SecImpact: Loss of landscape/sense of place  \
# 14                                             0
# 15                                             P
# 18                                             0
# 19                                             0
# 23                                             0
# ...                                          ...
# 3847                                           0
# 3850                                           P
# 3853                                           P
# 3855                                           P
# 3860                                           0
#
#      SecImpact: Other socio-economic impacts             Other Sec Impacts  \
# 14                                         0                           NaN
# 15                                         0                           NaN
# 18                                         0                           NaN
# 19                                         0                           NaN
# 23                                         0  loss of revenue from tourism
# ...                                      ...                           ...
# 3847                                       0                           NaN
# 3850                                       0                           NaN
# 3853                                       0          Desecration of tombs
# 3855                                       0                           NaN
# 3860                                       0                           NaN
#
#                                              References  \
# 14    Bullard, Robert D., and Beverly H. Wright. "Th...
# 15    Cutter, Susan L. "Race, class and environmenta...
# 18                                                  NaN
# 19    'Laid to Waste', by Robert Bahar and George Mc...
# 23                                                  NaN
# ...                                                 ...
# 3847  [2] Sörlin, S., Dale, B., Keeling, A., Larsen,...
# 3850                                                NaN
# 3853                                                NaN
# 3855  [2] TOTAL E&P ITALIA IN BASILICATA | Rapporto ...
# 3860  Metalclad y Guadalcázar. Cuadernos del centro....
#
#                                            Legislations  \
# 14    EPA's Hazardous Waste Facility Permit\nhttp://...
# 15                                                  NaN
# 18                                                  NaN
# 19    Court Case 'Chester Residents Concerned for Qu...
# 23    The Constitution of the United Republic of Tan...
# ...                                                 ...
# 3847  [7] Answer to Enquiry, Requested by: Rebecca W...
# 3850                                                NaN
# 3853                                                NaN
# 3855  [3] DELIBERAZIONE CIPE 21 dicembre 2001, n. 12...
# 3860  (5) Resolución. Metalclad Corporation c. los E...
#
#                                                Weblinks  \
# 14    University of Michigan's Environmental Justice...
# 15    Environmental Injustice in North Caroline\nhtt...
# 18    2,- The Kettelman Hills Facility - the company...
# 19    'Environmental Racism in Chester' by Mike Ewal...
# 23    (2)\nhttp://www.unpo.org/article/13509\n\nFact...
# ...                                                 ...
# 3847  [3] Wikimapia: Black Angel Lead/Zinc Mine\nhtt...
# 3850  [3]OCMAL . Conflicto Minero: Comunidad de Penc...
# 3853  [9] Evion Group. (n.d.). Maniry Project. Retri...
# 3855  [9] Articolo del quotidiano "Il Fatto Quotidia...
# 3860  (1) Angelica Enciso. La Jornada, 7 enero 2008....
#
#                                              Medialinks  \
# 14                                                  NaN
# 15    Image from Ricky Stillely Photography and the ...
# 18    Youtube Video: Birth defects linked to polluti...
# 19    Chester Environmental Justice, It contains por...
# 23                                                  NaN
# ...                                                 ...
# 3847                                                NaN
# 3850  17 - Parque para Penco\nhttps://www.instagram....
# 3853                                                NaN
# 3855  Video inchiesta: L'odore amaro del petrolio\nh...
# 3860  Documental Guadalcazar.31 de octubre de 2017. ...
#
#                    Created At              Modified At  \
# 14    2014-03-11 19:18:10 UTC  2015-07-08 09:47:03 UTC
# 15    2014-03-11 19:18:11 UTC  2015-07-08 09:49:35 UTC
# 18    2014-03-11 19:18:12 UTC  2023-08-16 11:19:24 UTC
# 19    2014-03-11 19:18:12 UTC  2015-07-08 09:48:45 UTC
# 23    2014-03-11 19:18:15 UTC  2014-04-08 15:06:37 UTC
# ...                       ...                      ...
# 3847  2023-06-26 20:46:21 UTC  2023-07-30 06:24:15 UTC
# 3850  2023-07-11 22:26:25 UTC  2023-07-11 22:26:25 UTC
# 3853  2023-07-28 12:11:00 UTC  2023-08-15 13:46:09 UTC
# 3855  2023-08-05 10:15:05 UTC  2023-08-05 10:15:06 UTC
# 3860  2023-08-15 17:27:13 UTC  2023-08-17 06:46:27 UTC
#
#                          geometry
# 14     POINT (-88.30881 32.79669)
# 15     POINT (-78.17391 36.33691)
# 18    POINT (-119.96369 35.99865)
# 19     POINT (-75.40559 39.82515)
# 23      POINT (36.13565 -2.28398)
# ...                           ...
# 3847   POINT (-51.27330 71.12240)
# 3850  POINT (-72.96250 -36.73500)
# 3853   POINT (44.81668 -24.49994)
# 3855    POINT (16.04154 40.38044)
# 3860  POINT (-100.39780 22.62383)
#
# [1101 rows x 264 columns]

# %%
poly_m.set_index('row.id', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11232\1469173797.py in ?()
# ----> 1 poly_m.set_index('row.id', inplace=True)
#
# c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6102                     if not found:
#    6103                         missing.append(col)
#    6104
#    6105         if missing:
# -> 6106             raise KeyError(f"None of {missing} are in the columns")
#    6107
#    6108         if inplace:
#    6109             frame = self
#
# KeyError: "None of ['row.id'] are in the columns"

# %%
poly_m
# Out:
#             area        admin adm0_a3  \
# row.id
# 1       0.038096  New Zealand     NZL
# 2       0.114247  New Zealand     NZL
# 3       0.125528  New Zealand     NZL
# 4       0.288590  New Zealand     NZL
# 5       0.349819  New Zealand     NZL
# ...          ...          ...     ...
# 81558   0.055417        China     CHN
# 81559   0.034229        China     CHN
# 81560   0.031565        China     CHN
# 81561   0.062556        China     CHN
# 81562   0.004362        China     CHN
#
#                                       list_of_commodities  \
# row.id
# 1       Ilmenite,Rutile,Zircon,Heavy Mineral Sands,Gol...
# 2       Ilmenite,Rutile,Zircon,Heavy Mineral Sands,Gol...
# 3                              Molybdenum,Tin,Silver,Gold
# 4                                                    Coal
# 5                                                    Coal
# ...                                                   ...
# 81558                                                None
# 81559                                                None
# 81560                                                None
# 81561                                                None
# 81562                                                None
#
#                                                  geometry  \
# row.id
# 1       MULTIPOLYGON (((19087285.169 -5226968.049, 190...
# 2       MULTIPOLYGON (((19067292.189 -5226485.372, 190...
# 3       MULTIPOLYGON (((19021695.725 -5290519.589, 190...
# 4       MULTIPOLYGON (((18702743.120 -5773509.154, 187...
# 5       MULTIPOLYGON (((18689039.691 -5763826.743, 186...
# ...                                                   ...
# 81558   MULTIPOLYGON (((12348122.854 5028774.758, 1234...
# 81559   MULTIPOLYGON (((12346584.096 5028356.281, 1234...
# 81560   MULTIPOLYGON (((12346694.124 5027979.011, 1234...
# 81561   MULTIPOLYGON (((12207108.511 5054984.962, 1220...
# 81562   MULTIPOLYGON (((12215216.521 5019956.918, 1221...
#
#                                                  buf_50km
# row.id
# 1       POLYGON ((19137298.168 -5227208.984, 19137057....
# 2       POLYGON ((19117219.375 -5226688.032, 19116978....
# 3       POLYGON ((19071446.837 -5290576.631, 19071206....
# 4       POLYGON ((18752847.566 -5773769.063, 18752606....
# 5       POLYGON ((18739407.872 -5764273.104, 18739167....
# ...                                                   ...
# 81558   POLYGON ((12397940.615 5028738.683, 12397699.8...
# 81559   POLYGON ((12396443.887 5028311.265, 12396203.1...
# 81560   POLYGON ((12396576.757 5027940.045, 12396335.9...
# 81561   POLYGON ((12257271.344 5054714.981, 12257030.5...
# 81562   POLYGON ((12265203.293 5019940.227, 12264962.5...
#
# [81562 rows x 6 columns]

# %%
ptrans = poly_m.set_geometry('buf_50km').to_crs('EPSG:4326')

# %%
ptrans.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Perform spatial join with the subset dataframe
polcon50 = ptrans.sjoin(cg, how='inner')

# %%
polcon50.head()
# Out:
#             area      admin adm0_a3    list_of_commodities  \
# row.id
# 73      2.051102  Argentina     ARG  Gold,Silver,Lead,Zinc
# 74      0.040568  Argentina     ARG  Gold,Silver,Lead,Zinc
# 75      0.335809  Argentina     ARG  Gold,Silver,Lead,Zinc
# 76      1.123157  Argentina     ARG  Gold,Silver,Lead,Zinc
# 77      0.018552  Argentina     ARG  Gold,Silver,Lead,Zinc
#
#                                                  geometry  \
# row.id
# 73      MULTIPOLYGON (((-69.49830 -48.77840, -69.49710...
# 74      MULTIPOLYGON (((-69.47550 -48.78930, -69.47510...
# 75      MULTIPOLYGON (((-69.51450 -48.79370, -69.51520...
# 76      MULTIPOLYGON (((-69.49990 -48.79360, -69.50020...
# 77      MULTIPOLYGON (((-69.57850 -48.84420, -69.57880...
#
#                                                  buf_50km  index_right  \
# row.id
# 73      POLYGON ((-69.03776 -48.77587, -69.03992 -48.8...          571
# 74      POLYGON ((-69.02587 -48.78871, -69.02803 -48.8...          571
# 75      POLYGON ((-69.06092 -48.79688, -69.06308 -48.8...          571
# 76      POLYGON ((-69.04256 -48.79538, -69.04472 -48.8...          571
# 77      POLYGON ((-69.12874 -48.84507, -69.13090 -48.8...          571
#
#         Conflict Id    Country  \
# row.id
# 73              733  Argentina
# 74              733  Argentina
# 75              733  Argentina
# 76              733  Argentina
# 77              733  Argentina
#
#                                                      Case  ...  \
# row.id                                                     ...
# 73      Manantial Espejo, gold and silver mining, Sant...  ...
# 74      Manantial Espejo, gold and silver mining, Sant...  ...
# 75      Manantial Espejo, gold and silver mining, Sant...  ...
# 76      Manantial Espejo, gold and silver mining, Sant...  ...
# 77      Manantial Espejo, gold and silver mining, Sant...  ...
#
#        SecImpact: Land dispossession  \
# row.id
# 73                                 0
# 74                                 0
# 75                                 0
# 76                                 0
# 77                                 0
#
#        SecImpact: Loss of landscape/sense of place  \
# row.id
# 73                                               P
# 74                                               P
# 75                                               P
# 76                                               P
# 77                                               P
#
#         SecImpact: Other socio-economic impacts  Other Sec Impacts  \
# row.id
# 73                                            0                NaN
# 74                                            0                NaN
# 75                                            0                NaN
# 76                                            0                NaN
# 77                                            0                NaN
#
#                                                References Legislations  \
# row.id
# 73      Observatorio de Conflictos Mineros de America ...          NaN
# 74      Observatorio de Conflictos Mineros de America ...          NaN
# 75      Observatorio de Conflictos Mineros de America ...          NaN
# 76      Observatorio de Conflictos Mineros de America ...          NaN
# 77      Observatorio de Conflictos Mineros de America ...          NaN
#
#                                                  Weblinks  \
# row.id
# 73      "Mueren dos jóvenes operarios en accidente en ...
# 74      "Mueren dos jóvenes operarios en accidente en ...
# 75      "Mueren dos jóvenes operarios en accidente en ...
# 76      "Mueren dos jóvenes operarios en accidente en ...
# 77      "Mueren dos jóvenes operarios en accidente en ...
#
#                                                Medialinks  \
# row.id
# 73      Video "Manantial Espejo, una mina por dentro"....
# 74      Video "Manantial Espejo, una mina por dentro"....
# 75      Video "Manantial Espejo, una mina por dentro"....
# 76      Video "Manantial Espejo, una mina por dentro"....
# 77      Video "Manantial Espejo, una mina por dentro"....
#
#                      Created At              Modified At
# row.id
# 73      2014-03-11 19:26:18 UTC  2020-01-11 14:53:45 UTC
# 74      2014-03-11 19:26:18 UTC  2020-01-11 14:53:45 UTC
# 75      2014-03-11 19:26:18 UTC  2020-01-11 14:53:45 UTC
# 76      2014-03-11 19:26:18 UTC  2020-01-11 14:53:45 UTC
# 77      2014-03-11 19:26:18 UTC  2020-01-11 14:53:45 UTC
#
# [5 rows x 270 columns]

# %%
gr = polcon50.groupby('row.id')['Conflict Id'].count().reset_index()

# %%
gr.rename(columns={'Conflict Id': 'conflicts'}, inplace=True)

# %%
gr.head()
# Out:
#    row.id  conflicts
# 0      73          1
# 1      74          1
# 2      75          1
# 3      76          1
# 4      77          1

# %%
sns.histplot(data = gr['conflicts'])

plt.title('Number of conflicts within 50 km buffer of mining sites')

plt.savefig('fig/conf_per_mine_50k.png')

# %%
polcon50['mine_id'] =polcon50.index

# %%
cpm = polcon50.groupby('Conflict Id')['mine_id'].count().reset_index()

# %%
cpmplot = cpm.rename(columns={'mine_id': 'mines'})

# %%
sns.histplot(data = cpmplot.mines, bins=20, log_scale=True, kde = True)

plt.title('Number of mines allocated to a conflict 50 km buffer around a mine')
plt.savefig('fig/mine_per_con.png')

# %%
sub = polcon50['Conflict Id']

# %%
sub.rename('conflict_id', inplace=True)
# Out:
# row.id
# 73        733
# 74        733
# 75        733
# 76        733
# 77        733
#          ...
# 81423    2920
# 81430    4395
# 81431    4395
# 81432    3814
# 81433    3814
# Name: conflict_id, Length: 15081, dtype: int64

# %%
coo = pd.crosstab(sub.index, sub.values)

# %%
ad = coo.dot(coo.T)

# %%
np.fill_diagonal(ad.values, 0)

# %%
G = nx.from_pandas_adjacency(ad)

# %%
# Draw the nodes
pos = nx.spring_layout(G)  # Define the layout of the nodes
nx.draw_networkx_nodes(G, pos, node_size=10, node_color='skyblue', alpha=0.7)

# Draw the edges
nx.draw_networkx_edges(G, pos, width=2, alpha=1, edge_color='gray')

# Display the graph
plt.axis('off')  # Turn off axis
plt.show()

# %%
cpm
# Out:
#      Conflict Id  mine_id
# 0             24        2
# 1             42        8
# 2             57        8
# 3             76        7
# 4             90        5
# ..           ...      ...
# 689         6332       14
# 690         6335        8
# 691         6371        1
# 692         6376        1
# 693         6393       16
#
# [694 rows x 2 columns]

# %%
polyn = copy.deepcopy(poly).set_index('row.id')

# %%
gr
# Out:
#        row.id  conflicts
# 0          73          1
# 1          74          1
# 2          75          1
# 3          76          1
# 4          77          1
# ...       ...        ...
# 10036   81423          6
# 10037   81430          1
# 10038   81431          1
# 10039   81432          1
# 10040   81433          1
#
# [10041 rows x 2 columns]

# %%
j = polyn.merge(gr, how='left', on='row.id')

# %%
j.conflicts = j.conflicts.fillna(0)

# %%
type(j)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
j[j.conflicts !=0].shape
# Out:
# (10041, 7)

# %%
j.set_geometry('geometry')
# Out:
#        row.id      area        admin adm0_a3  \
# 0           1  0.038096  New Zealand     NZL
# 1           2  0.114247  New Zealand     NZL
# 2           3  0.125528  New Zealand     NZL
# 3           4  0.288590  New Zealand     NZL
# 4           5  0.349819  New Zealand     NZL
# ...       ...       ...          ...     ...
# 81557   81558  0.055417        China     CHN
# 81558   81559  0.034229        China     CHN
# 81559   81560  0.031565        China     CHN
# 81560   81561  0.062556        China     CHN
# 81561   81562  0.004362        China     CHN
#
#                                      list_of_commodities  \
# 0      Ilmenite,Rutile,Zircon,Heavy Mineral Sands,Gol...
# 1      Ilmenite,Rutile,Zircon,Heavy Mineral Sands,Gol...
# 2                             Molybdenum,Tin,Silver,Gold
# 3                                                   Coal
# 4                                                   Coal
# ...                                                  ...
# 81557                                               None
# 81558                                               None
# 81559                                               None
# 81560                                               None
# 81561                                               None
#
#                                                 geometry  conflicts
# 0      MULTIPOLYGON (((171.46400 -42.43900, 171.46250...        0.0
# 1      MULTIPOLYGON (((171.28440 -42.43580, 171.28290...        0.0
# 2      MULTIPOLYGON (((170.87480 -42.85890, 170.87220...        0.0
# 3      MULTIPOLYGON (((168.00960 -45.95730, 168.00900...        0.0
# 4      MULTIPOLYGON (((167.88650 -45.89680, 167.88620...        0.0
# ...                                                  ...        ...
# 81557  MULTIPOLYGON (((110.92507 41.11132, 110.92504 ...        0.0
# 81558  MULTIPOLYGON (((110.91125 41.10848, 110.91125 ...        0.0
# 81559  MULTIPOLYGON (((110.91224 41.10593, 110.91222 ...        0.0
# 81560  MULTIPOLYGON (((109.65832 41.28847, 109.65828 ...        0.0
# 81561  MULTIPOLYGON (((109.73116 41.05161, 109.73115 ...        0.0
#
# [81562 rows x 7 columns]

# %%
jind = j.set_index('row.id')

# %%
jind.to_file('data/interm/mine_con_50.gpkg', driver ='GPKG', engine='fiona')

# %%
from shapely.geometry import box

def grid_shape_constructor(resolution =1, min_long=-180, min_lat=-90, max_lon=180, max_lat=90):
    
    
    # Generate grid cells using list comprehensions
    grid_cells = [box(lon, lat, lon + resolution, lat + resolution)
                for lon in range(min_lon, max_lon, resolution)
                for lat in range(min_lat, max_lat, resolution)]

    # Create a GeoDataFrame from the grid cells

    grid = gpd.GeoDataFrame(geometry=grid_cells, crs='EPSG:4326')
    grid['id'] = np.arange(0,grid.shape[0])

    return grid

# Plot the grid
# grid_gdf.plot(facecolor='None', edgecolor='grey', linewidth=.1)

# %%
df= gpd.read_file('data/interm/mine_con_50.gpkg')

# %%
df.area.hist(log = True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_11232\1539893080.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   df.area.hist(log = True)
# <Axes: >

# %%
grid = grid_shape_constructor()

# %%
grid.head()
# Out:
#                                             geometry  id
# 0  POLYGON ((-179.00000 -90.00000, -179.00000 -89...   0
# 1  POLYGON ((-179.00000 -89.00000, -179.00000 -88...   1
# 2  POLYGON ((-179.00000 -88.00000, -179.00000 -87...   2
# 3  POLYGON ((-179.00000 -87.00000, -179.00000 -86...   3
# 4  POLYGON ((-179.00000 -86.00000, -179.00000 -85...   4

# %%
jgr = grid.sjoin(df)

# %%
gr = jgr.groupby('id')[['area', 'conflicts']].sum().reset_index()

# %%
gr.area.describe()
# Out:
# count    4541.000000
# mean       34.052237
# std       124.358421
# min         0.002733
# 25%         0.937177
# 50%         4.626202
# 75%        20.886341
# max      2548.993896
# Name: area, dtype: float64

# %%
gr.shape[0]
# Out:
# 4541

# %%
grid.shape[0]
# Out:
# 64800

# %%
jplot = grid.merge(gr, on='id')

# %%
jplot['con_dens'] = jplot['conflicts'] / jplot['area']

# %%
df.head

# %%
f,ax = plt.subplots(figsize=(10,4))
#jplot[jplot.conflicts ==0].plot( color='grey', alpha=.8, ax=ax) 

jplot.plot(column='con_dens', scheme='FisherJenks', k=4, legend=True, cmap ='crest', ax=ax) 

plt.legend(title='Conlict density in (1/km2)')
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\plotting.py:777: UserWarning: Numba not installed. Using slow pure python version.
#   binning = mapclassify.classify(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
